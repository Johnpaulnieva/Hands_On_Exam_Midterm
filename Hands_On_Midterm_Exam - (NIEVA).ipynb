# %% [markdown]
# <h2>CHICAGO CRIME ANALYSIS</h2>
# <hr>
# <h2>ANALYST : JOHN PAUL R. NIEVA</h2>

# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import folium
from folium.plugins import HeatMap
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
chicago = pd.read_csv("C:\\Users\\KRIANA\\Downloads\\Chicago_Crimes.csv")
chicago
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
#         IUCR         Primary Type                          Description  \
# 0       0890                THEFT                        FROM BUILDING
# 1       2825        OTHER OFFENSE              HARASSMENT BY TELEPHONE
# 2       0917  MOTOR VEHICLE THEFT        CYCLE, SCOOTER, BIKE WITH VIN
# 3       143A    WEAPONS VIOLATION        UNLAWFUL POSSESSION - HANDGUN
# 4       0890                THEFT                        FROM BUILDING
# ...      ...                  ...                                  ...
# 249118  2826        OTHER OFFENSE       HARASSMENT BY ELECTRONIC MEANS
# 249119  0430              BATTERY  AGGRAVATED - OTHER DANGEROUS WEAPON
# 249120  0486              BATTERY              DOMESTIC BATTERY SIMPLE
# 249121  0530              ASSAULT  AGGRAVATED - OTHER DANGEROUS WEAPON
# 249122  0710                THEFT             THEFT FROM MOTOR VEHICLE
#
#                 Location Description  Arrest  Domestic  ...  Ward  \
# 0                          APARTMENT   False     False  ...     3
# 1       COMMERCIAL / BUSINESS OFFICE   False     False  ...    25
# 2                             STREET   False     False  ...    36
# 3                             STREET    True     False  ...    28
# 4                          RESIDENCE   False     False  ...    21
# ...                              ...     ...       ...  ...   ...
# 249118                     APARTMENT   False     False  ...     1
# 249119                        STREET   False     False  ...     9
# 249120                     APARTMENT   False      True  ...    21
# 249121                        STREET    True     False  ...    20
# 249122                        STREET   False     False  ...    27
#
#         Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                 38.0        06     1178707.0    1878256.0  2024
# 1                 31.0        26     1161210.0    1889347.0  2024
# 2                 23.0        07     1146960.0    1909501.0  2024
# 3                 26.0        15     1150158.0    1898721.0  2024
# 4                 75.0        06     1170856.0    1830157.0  2024
# ...                ...       ...           ...          ...   ...
# 249118            22.0        26     1156478.0    1917149.0  2025
# 249119            49.0       04B     1175694.0    1842631.0  2025
# 249120            71.0       08B     1173850.0    1848976.0  2025
# 249121            61.0       04A     1169838.0    1871348.0  2025
# 249122            28.0        06     1168216.0    1902390.0  2025
#
#                     Updated On   Latitude  Longitude  \
# 0       12/21/2024 03:40:46 PM  41.821236 -87.619921
# 1       12/21/2024 03:40:46 PM  41.852052 -87.683801
# 2       12/21/2024 03:40:46 PM  41.907640 -87.735587
# 3       12/21/2024 03:40:46 PM  41.877997 -87.724121
# 4       12/21/2024 03:40:46 PM  41.689421 -87.650123
# ...                        ...        ...        ...
# 249118  04/19/2025 03:41:24 PM  41.928440 -87.700416
# 249119  04/19/2025 03:41:24 PM  41.723545 -87.632040
# 249120  04/19/2025 03:41:24 PM  41.740998 -87.638606
# 249121  04/19/2025 03:41:24 PM  41.802477 -87.652657
# 249122  04/19/2025 03:41:24 PM  41.887694 -87.657710
#
#                              Location
# 0       (41.821236024, -87.619920712)
# 1       (41.852051675, -87.683800849)
# 2       (41.907640473, -87.735587478)
# 3       (41.877997275, -87.724120826)
# 4         (41.6894214, -87.650123247)
# ...                               ...
# 249118  (41.928439867, -87.700415972)
# 249119  (41.723545182, -87.632039508)
# 249120   (41.74099774, -87.638606337)
# 249121  (41.802477219, -87.652657244)
# 249122  (41.887694407, -87.657710204)
#
# [249123 rows x 22 columns]

# %% [markdown]
# <h3><b>Descriptive Analytics</b></h3>

# %%
chicago.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  2.491230e+05  249123.000000  249123.000000  249123.000000
# mean   1.358652e+07    1153.845634      11.308924      23.186823
# std    6.473192e+05     707.959752       7.074807      13.925951
# min    2.807300e+04     111.000000       1.000000       1.000000
# 25%    1.352322e+07     533.000000       5.000000      10.000000
# 50%    1.361560e+07    1034.000000      10.000000      23.000000
# 75%    1.370865e+07    1732.000000      17.000000      34.000000
# max    1.381045e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate           Year  \
# count   249120.000000  2.490330e+05  2.490330e+05  249123.000000
# mean        36.238560  1.165309e+06  1.887602e+06    2024.241668
# std         21.567485  1.616814e+04  3.146277e+04       0.428095
# min          1.000000  1.092647e+06  1.813897e+06    2024.000000
# 25%         22.000000  1.153981e+06  1.860560e+06    2024.000000
# 50%         32.000000  1.167190e+06  1.894278e+06    2024.000000
# 75%         53.000000  1.176662e+06  1.910282e+06    2024.000000
# max         77.000000  1.205119e+06  1.951517e+06    2025.000000
#
#             Latitude      Longitude
# count  249033.000000  249033.000000
# mean       41.847162     -87.668845
# std         0.086517       0.058875
# min        41.644590     -87.934567
# 25%        41.772706     -87.710071
# 50%        41.865616     -87.661690
# 75%        41.909711     -87.627233
# max        42.022559     -87.524531

# %%
chicago.describe().T
# Out:
#                    count          mean            std           min  \
# ID              249123.0  1.358652e+07  647319.161410  2.807300e+04
# Beat            249123.0  1.153846e+03     707.959752  1.110000e+02
# District        249123.0  1.130892e+01       7.074807  1.000000e+00
# Ward            249123.0  2.318682e+01      13.925951  1.000000e+00
# Community Area  249120.0  3.623856e+01      21.567485  1.000000e+00
# X Coordinate    249033.0  1.165309e+06   16168.139632  1.092647e+06
# Y Coordinate    249033.0  1.887602e+06   31462.770629  1.813897e+06
# Year            249123.0  2.024242e+03       0.428095  2.024000e+03
# Latitude        249033.0  4.184716e+01       0.086517  4.164459e+01
# Longitude       249033.0 -8.766884e+01       0.058875 -8.793457e+01
#
#                          25%           50%           75%           max
# ID              1.352322e+07  1.361560e+07  1.370865e+07  1.381045e+07
# Beat            5.330000e+02  1.034000e+03  1.732000e+03  2.535000e+03
# District        5.000000e+00  1.000000e+01  1.700000e+01  3.100000e+01
# Ward            1.000000e+01  2.300000e+01  3.400000e+01  5.000000e+01
# Community Area  2.200000e+01  3.200000e+01  5.300000e+01  7.700000e+01
# X Coordinate    1.153981e+06  1.167190e+06  1.176662e+06  1.205119e+06
# Y Coordinate    1.860560e+06  1.894278e+06  1.910282e+06  1.951517e+06
# Year            2.024000e+03  2.024000e+03  2.024000e+03  2.025000e+03
# Latitude        4.177271e+01  4.186562e+01  4.190971e+01  4.202256e+01
# Longitude      -8.771007e+01 -8.766169e+01 -8.762723e+01 -8.752453e+01

# %% [markdown]
# <h3>Checking Null Values</h3>

# %%
chicago.isnull().sum()
# Out:
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description    857
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                      0
# Community Area            3
# FBI Code                  0
# X Coordinate             90
# Y Coordinate             90
# Year                      0
# Updated On                0
# Latitude                 90
# Longitude                90
# Location                 90
# dtype: int64

# %% [markdown]
# <h3>Filling Up Null Values</h3>

# %%
chicago['Location Description'] = chicago['Location Description'].fillna(chicago['Location Description'].mode()[0])
chicago['Community Area'] = chicago['Community Area'].fillna(chicago['Community Area'].mean())
chicago['X Coordinate'] = chicago['X Coordinate'].fillna(chicago['X Coordinate'].mean())
chicago['Y Coordinate'] = chicago['Y Coordinate'].fillna(chicago['Y Coordinate'].mean())
chicago['Latitude'] = chicago['Latitude'].fillna(chicago['Latitude'].mean())
chicago['Longitude'] = chicago['Longitude'].fillna(chicago['Longitude'].mean())
chicago['Location'] = chicago['Location'].fillna(chicago['Location'].mode()[0])

# %%
chicago.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %% [markdown]
# <h3>Categorical Data</h3>

# %%
chicago['Case Number'] = chicago['Case Number'].astype('category')
chicago['Date'] = chicago['Date'].astype('category')
chicago['Block'] = chicago['Block'].astype('category')
chicago['IUCR'] = chicago['IUCR'].astype('category')
chicago['Primary Type'] = chicago['Primary Type'].astype('category')
chicago['Description'] = chicago['Description'].astype('category')
chicago['Location Description'] = chicago['Location Description'].astype('category')
chicago['FBI Code'] = chicago['FBI Code'].astype('category')
chicago['Updated On'] = chicago['Updated On'].astype('category')
chicago['Location'] = chicago['Location'].astype('category')

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249123 entries, 0 to 249122
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    249123 non-null  int64
#  1   Case Number           249123 non-null  category
#  2   Date                  249123 non-null  category
#  3   Block                 249123 non-null  category
#  4   IUCR                  249123 non-null  category
#  5   Primary Type          249123 non-null  category
#  6   Description           249123 non-null  category
#  7   Location Description  249123 non-null  category
#  8   Arrest                249123 non-null  bool
#  9   Domestic              249123 non-null  bool
#  10  Beat                  249123 non-null  int64
#  11  District              249123 non-null  int64
#  12  Ward                  249123 non-null  int64
#  13  Community Area        249123 non-null  float64
#  14  FBI Code              249123 non-null  category
#  15  X Coordinate          249123 non-null  float64
#  16  Y Coordinate          249123 non-null  float64
#  17  Year                  249123 non-null  int64
#  18  Updated On            249123 non-null  category
#  19  Latitude              249123 non-null  float64
#  20  Longitude             249123 non-null  float64
#  21  Location              249123 non-null  category
# dtypes: bool(2), category(10), float64(5), int64(5)
# memory usage: 46.4 MB

# %% [markdown]
# <h3>Clearing any Inconsistencies with the Dataset</h3>

# %%
chicago['Date'] = chicago['Date'].str.strip()
chicago['Date'] = chicago['Date'].astype('str')
chicago['Date'] = chicago['Date'].str.replace('/', '-')

# %%
chicago['Date'] = pd.to_datetime(chicago['Date'], dayfirst = True, errors = 'coerce')

# %%
chicago['Year'] = chicago['Date'].dt.year
chicago['Month'] = chicago['Date'].dt.month
chicago['Day'] = chicago['Date'].dt.day
chicago['DayOfWeek'] = chicago['Date'].dt.dayofweek

# %%
chicago.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# Month                   0
# Day                     0
# DayOfWeek               0
# dtype: int64

# %%
chicago.dtypes
# Out:
# ID                               int64
# Case Number                   category
# Date                    datetime64[ns]
# Block                         category
# IUCR                          category
# Primary Type                  category
# Description                   category
# Location Description          category
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                             int64
# Community Area                 float64
# FBI Code                      category
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int32
# Updated On                    category
# Latitude                       float64
# Longitude                      float64
# Location                      category
# Month                            int32
# Day                              int32
# DayOfWeek                        int32
# dtype: object

# %% [markdown]
# <h1>Thirty-five (35) Insight</h1>

# %% [markdown]
# <h3>Which are the top 5 most common types of crimes in Chicago?</h3>

# %%
plt.figure(figsize=(10,5))
sns.countplot(
    data=chicago, 
    x='Primary Type', 
    order=chicago['Primary Type'].value_counts().index[:5], 
    palette='viridis'
)
plt.xticks(rotation=45)
plt.title("Top 5 Most Common Crime Types")
plt.ylabel("Count")
plt.xlabel("Crime Type")
plt.show()

# %% [markdown]
# <h3>INSIGHT 1 : Most crimes in Chicago are thefts, way more than any other type. After that, battery comes next, but still much less than theft. Crimes like criminal damage, assault, and motor vehicle theft happen often too, but they’re not as common. So overall, stealing (especially theft) is the biggest crime problem in the city.</h3>

# %% [markdown]
# <h3>How many crimes were reported each year?</h3>

# %%
plt.figure(figsize=(10,5))
sns.countplot(
    data=chicago,
    x='Year',
    order=chicago['Year'].value_counts().index.sort_values(),
    palette='magma'
)
plt.xticks(rotation=45)
plt.title("Number of Crimes Reported per Year")
plt.ylabel("Count")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# <h3>INSIGHT 2 : In 2024, there were way more crimes reported than in 2025. This suggests that crime counts have dropped in 2025 compared to the previous year.<h3>

# %% [markdown]
# <h3>INSIGHT 3 : 2025 has fewer crimes recorded, but this might be because the year isn’t finished yet. The data for 2025 could still increase as more months are added.<h3>

# %% [markdown]
# <h3>What percentage of crimes resulted in an arrest?</h3>

# %%
arrest_counts = chicago['Arrest'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    arrest_counts, 
    labels=arrest_counts.index, 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=['#66b3ff','#ff9999']
)
plt.title("Percentage of Crimes Resulting in Arrest")
plt.show()

# %% [markdown]
# <h3>INSIGHT 4 : Only about 14.5% of crimes in Chicago lead to an arrest, while the majority 85.5% do not result in an arrest.<h3>

# %% [markdown]
# <h3>Which month records the highest number of crimes in a year?</h3>

# %%
chicago['Month'] = chicago['Date'].dt.month

crimes_per_month = chicago['Month'].value_counts().sort_index()

month_names = {
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
}
crimes_per_month.index = crimes_per_month.index.map(month_names)

plt.figure(figsize=(12,6))
colors = sns.color_palette("tab20", 12) 
crimes_per_month.plot(kind='bar', color=colors)

plt.title("Total Crimes per Month", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Number of Crimes")
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>INSIGHT 5 : July has the highest number of crimes compared to all other months.<h3>

# %% [markdown]
# <h3>INSIGHT 6 : February and December show the lowest crime numbers, meaning crime tends to dip at the start and end of the year.<h3>

# %% [markdown]
# <h3>INSIGHT 7 : From May to October, crime stays relatively high, showing that warmer months might have more crime activity.<h3>

# %% [markdown]
# <h3>How do different numerical crime features relate to each other?</h3>

# %%
numeric_cols = ['Year', 'Month', 'Day', 'X Coordinate', 'Y Coordinate']

sns.pairplot(chicago[numeric_cols], diag_kind='kde', corner=True, plot_kws={'alpha':0.5})
plt.suptitle("Pairplot of Numerical Crime Features", y=1.02)
plt.show()

# %% [markdown]
# <h3>INSIGHT 8 : The scatterplots show that crimes are spread throughout the months and days, meaning crime happens regularly across the year without big gaps.<h3>

# %% [markdown]
# <h3>INSIGHT 9 : The X and Y coordinates form a clear cluster, showing that most crimes are concentrated in specific areas of Chicago, not evenly spread out everywhere.<h3>

# %% [markdown]
# <h3>How does the distribution of crimes vary across different days of the week?</h3>

# %%
plt.figure(figsize=(10,6))
sns.violinplot(
    data=chicago, 
    x='DayOfWeek', 
    y='Month', 
    palette='Set2'
)
plt.title("Distribution of Crimes by Day of the Week")
plt.xlabel("Day of the Week (1=Mon, 7=Sun)")
plt.ylabel("Month")
plt.show()

# %% [markdown]
# <h3>INSIGHT 10 : Crimes occur fairly evenly across all days of the week. The width of each violin is very similar, showing that no single day (Monday to Sunday) experiences a significantly higher or lower concentration of crime.<h3>

# %% [markdown]
# <h3>Which types of crimes are most common in Chicago?</h3>

# %%
crime_types = chicago['Primary Type'].value_counts().head(10)

plt.figure(figsize=(10,6))
crime_types.plot(kind='barh', color='skyblue', edgecolor='black')

plt.title("Top 10 Most Common Crime Types in Chicago")
plt.xlabel("Number of Crimes")
plt.ylabel("Crime Type")
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# <h3>INSIGHT 11 : The chart shows that Theft and Battery are the two most common crimes in Chicago, far more frequent than other types. This suggests that property-related and personal confrontations are the biggest crime concerns in the city.<h3>

# %% [markdown]
# <h3>How have crime trends changed over the years in Chicago?</h3>

# %%
crimes_per_year = chicago.groupby(chicago['Date'].dt.year).size()

plt.figure(figsize=(12,6))
plt.plot(crimes_per_year.index, crimes_per_year.values, marker='o', linestyle='-', color='teal')

plt.title("Trend of Crimes in Chicago Over the Years", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Crimes", fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h3>INSIGHT 12 : The line graph shows that crime numbers change from year to year, with some years having more reported crimes while others show a clear drop.<h3>

# %% [markdown]
# <h3>What are the top 20 locations in Chicago where crimes most often occur?</h3>

# %%
crime_locations = chicago['Location Description'].value_counts().head(20)

plt.figure(figsize=(10,6))
crime_locations.plot(kind='barh', color='coral', edgecolor='black')

plt.title("Top 20 Crime Locations in Chicago")
plt.xlabel("Number of Crimes")
plt.ylabel("Location")
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# <h3>INSIGHT 13 : Streets have the highest number of crimes by far, making them the top hotspot for criminal activities in Chicago.<h3>

# %% [markdown]
# <h3>INSIGHT 14 : After streets, crimes occur most often in apartments and residential homes, showing that both public and private spaces are vulnerable.<h3>

# %% [markdown]
# <h3>INSIGHT 15 : Places like restaurants, gas stations, and stores show much fewer incidents compared to streets and residences, meaning most crimes happen in daily living and transit spaces rather than commercial spots.<h3>

# %% [markdown]
# <h3>INSIGHT 16 : Sidewalks and parking lots also appear as common crime locations, showing that many incidents happen in open public areas where people walk or park their cars.<h3>

# %% [markdown]
# <h3>lowest 20 crime locations in Chicago?</h3>

# %%
lowest_crime_locations = chicago['Location Description'].value_counts().tail(20)

plt.figure(figsize=(10,6))
lowest_crime_locations.plot(kind='barh', color='lightgreen', edgecolor='black')

plt.title("Lowest 20 Crime Locations in Chicago")
plt.xlabel("Number of Crimes")
plt.ylabel("Location")
plt.show()

# %% [markdown]
# <h3>INSIGHT 17 : Crimes are least common in places like taverns, basements, and driveways, showing that incidents happen far less often in private or low-traffic areas compared to busy public spaces like streets or apartments.<h3>

# %%
# Create a copy to avoid modifying the original dataset
corr_df = chicago.copy()

# Convert Arrest (True/False) to numeric (1 = Arrest, 0 = No Arrest)
corr_df['Arrest_Num'] = corr_df['Arrest'].astype(int)

# Convert Domestic (True/False) to numeric (1 = Domestic Crime, 0 = Non-Domestic)
corr_df['Domestic_Num'] = corr_df['Domestic'].astype(int)

# Select relevant numeric columns for correlation
correlation_matrix = corr_df[['Arrest_Num', 'Domestic_Num', 'Year', 'Month', 'Day', 'DayOfWeek']].corr()

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,        # Show correlation values
    fmt=".2f",         # Format values to 2 decimal places
    cmap='coolwarm',   # Blue=negative, Red=positive
    center=0,          # Center at 0 correlation
    linewidths=0.5
)

plt.title('Correlation Between Crime Factors in Chicago', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>On which day of the week do most crimes in Chicago occur?</h3>

# %%
# Count crimes by day of the week
crimes_by_day = chicago['DayOfWeek'].value_counts().sort_index()

# Map numbers to day names for clarity
day_names = {1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat', 7: 'Sun'}
crimes_by_day.index = crimes_by_day.index.map(day_names)

# Plot bar chart
plt.figure(figsize=(10,6))
crimes_by_day.plot(kind='bar', color='orange', edgecolor='black')

plt.title("Number of Crimes by Day of the Week in Chicago")
plt.xlabel("Day of the Week")
plt.ylabel("Number of Crimes")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <h3>INSIGHT 18 :Crimes in Chicago happen every day of the week, but some days show higher counts. The busiest days are usually toward the weekend, while midweek tends to have fewer crimes.<h3>

# %% [markdown]
# <h3>How is the distribution of crimes spread across different months in Chicago?</h3>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(
    data=chicago,
    x='Month',
    y='DayOfWeek',
    palette='muted',
    inner='quartile'
)

plt.title("Distribution of Crimes by Month and Day of the Week in Chicago", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Day of the Week (1=Mon, 7=Sun)")
plt.show()

# %% [markdown]
# <h3>INSIGHT 19 : Crimes happen in all months and on all days, but the violins show that crime is spread fairly evenly without one month or day standing out too much. This means Chicago crimes aren’t tied to a specific season or weekday they occur consistently throughout the year.<h3>

# %% [markdown]
# <h3>INSIGHT 20 : The shape of the violins shows that crimes are not clustered in just a few days instead, they are spread out, meaning crime happens regularly across both weekdays and weekends in every month.<h3>

# %% [markdown]
# <h3>What is the distribution of crimes by Month and Year in Chicago?</h3>

# %%
heatmap_month_year = chicago.groupby(['Month', 'Year']).size().unstack(fill_value=0)

plt.figure(figsize=(12,6))
sns.heatmap(heatmap_month_year, cmap="Blues", annot=True, fmt="d", cbar=True)

plt.title("Crimes by Month and Year", fontsize=16, fontweight='bold')
plt.xlabel("Year", fontsize=12)
plt.ylabel("Month", fontsize=12)
plt.show()

# %% [markdown]
# <h3>INSIGHT 21 : Crimes in 2024 were highest during the middle of the year (April–October), especially in May, July, and August. This suggests that crimes increase during warmer months.<h3>

# %% [markdown]
# <h3>INSIGHT 22 : In 2025, crime counts are much lower compared to 2024, but early months (January–March) already show thousands of cases, meaning the trend of crimes happening all year round continues.<h3>

# %% [markdown]
# <h3>What is the percentage distribution of crimes by Primary Type in Chicago for 2024?</h3>

# %%
crimes_2024 = chicago[chicago['Year'] == 2024]

crime_type_counts = crimes_2024['Primary Type'].value_counts().head(10)  # top 10 types

plt.figure(figsize=(8,8))
plt.pie(crime_type_counts, labels=crime_type_counts.index, autopct='%1.1f%%', startangle=140)

plt.title("Percentage Distribution of Crimes by Primary Type (2024)", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <h3>INSIGHT 23 : Theft and Battery together make up almost half of all crimes in 2024. This shows that a large portion of criminal activity is concentrated on stealing and physical confrontations, making them the two biggest challenges for law enforcement and the community.<h3>

# %% [markdown]
# <h3>INSIGHT 24 : Motor Vehicle Theft accounts for almost 9% of all crimes in 2024, making it one of the top crime categories. This shows that car-related crimes are a serious issue in Chicago, not only causing financial loss to victims but also affecting public safety. The data suggests that stronger vehicle security measures and community awareness could help reduce these cases.<h3>

# %% [markdown]
# <h3>INSIGHT 25 : Crimes like Robbery, Burglary, and Weapons Violations make up less than 5% each of the total crimes in 2024. Even though their percentages are smaller compared to Theft or Battery, they are still serious because they often involve violence or danger to people. This means that while they are less frequent, their impact on communities can be much greater.<h3>

# %% [markdown]
# <h3>What is the average latitude of reported crimes in Chicago for each year?</h3>

# %%
avg_latitude = chicago.groupby('Year')['Latitude'].mean()

plt.figure(figsize=(10,5))
avg_latitude.plot(kind='line', marker='o')

plt.title("Average Latitude of Reported Crimes in Chicago by Year", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Average Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# <h3>INSIGHT 26 : The chart shows that the average latitude of reported crimes in Chicago dropped slightly from 2024 to 2025. This means crimes shifted a bit further south within the city. While the change is small, it may suggest that certain neighborhoods in the southern part of Chicago started reporting more crimes compared to the north. This kind of geographic trend is important because it can help city officials and police focus resources where they are most needed.<h3>

# %% [markdown]
# <h3>What is the average longitude of reported crimes in Chicago for each year?</h3>

# %%
avg_longitude = chicago.groupby('Year')['Longitude'].mean()

plt.figure(figsize=(8,5))
avg_longitude.plot(kind='bar', color='orange')

plt.title("Average Longitude of Reported Crimes in Chicago by Year", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Average Longitude")
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# <h3>INSIGHT 27 : The graph shows that the average longitude of crimes in Chicago remained almost unchanged from 2024 to 2025. This means crimes are still concentrated in the same east–west areas of the city, suggesting that the same neighborhoods continue to face recurring crime issues.<h3>

# %% [markdown]
# <h3>Which community areas in Chicago had the highest number of reported crimes in 2024?</h3>

# %%
crimes_2024 = chicago[chicago['Year'] == 2024]

community_crimes = crimes_2024['Community Area'].value_counts().head(10)  # Top 10 areas

plt.figure(figsize=(10,6))
community_crimes.plot(kind='bar', color='teal')

plt.title("Top 10 Community Areas with Reported Crimes in Chicago (2024)", fontsize=14, fontweight='bold')
plt.xlabel("Community Area")
plt.ylabel("Number of Crimes")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# <h3>INSIGHT 28 : Community Area 25 had the highest number of reported crimes in 2024, with over 9,000 cases. This shows that crime is not evenly distributed across Chicago certain areas are much more affected than others. The big gap between the top areas and the lower ones suggests that local conditions, like population size, economic challenges, or neighborhood activity, may play a strong role in crime levels.<h3>

# %% [markdown]
# <h3>INSIGHT 29 : The top 10 community areas alone accounted for a very large portion of total crimes in 2024. For example, Community Areas 8, 28, and 32 also had thousands of cases each. This means crime is concentrated, and by focusing police presence or community programs in these neighborhoods, the city could potentially make a big impact on overall crime reduction.</h3>

# %% [markdown]
# <h3>INSIGHT 30 : Even though Community Areas like 43, 24, and 23 are not at the very top of the list, they still had between 5,000–6,000 crimes in 2024. This tells us that crime is not just a problem in the “highest-crime” neighborhoods it also affects many mid-level areas. These places might not get as much attention, but the numbers show they also need strong safety measures and community support.<h3>

# %% [markdown]
# <h3>Is there a relationship between Latitude and Longitude in the Chicago crime dataset?</h3>

# %%
corr_value = chicago[['Latitude', 'Longitude']].corr()

plt.figure(figsize=(5,4))
sns.heatmap(corr_value, annot=True, cmap="coolwarm", cbar=True)
plt.title("Correlation between Latitude and Longitude in Chicago Crimes")
plt.show()

print("Correlation between Latitude and Longitude:")
print(corr_value)
# Out:
# Correlation between Latitude and Longitude:
#            Latitude  Longitude
# Latitude   1.000000  -0.515355
# Longitude -0.515355   1.000000

# %% [markdown]
# <h3>INSIGHT 31 : The correlation between Latitude and Longitude in Chicago crime data is about -0.52, which means they are moderately negatively related. This tells us that when crimes happen further north in Chicago (higher latitude), they are usually located a bit more to the west (lower longitude). It shows that the crime locations follow the city’s real map pattern instead of being random.<h3>

# %% [markdown]
# <h3>Is there any visible relationship between the number of arrests, year, and community areas in Chicago crimes?</h3>

# %%
pair_data = chicago[['Year', 'Community Area', 'Arrest']].copy()

pair_data['Arrest'] = pair_data['Arrest'].astype(int)

pair_data = pair_data.dropna()

sns.pairplot(pair_data, diag_kind="kde", plot_kws={'alpha':0.3, 's':10})
plt.suptitle("Pairplot of Year, Community Area, and Arrests in Chicago Crimes", y=1.02, fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <h3>INSIGHT 32 : The pairplot shows that arrests happened every year, but the overall trend of arrests closely follows the number of reported crimes per year. This means that in years with more crimes, there were also more arrests.<h3>

# %% [markdown]
# <h3>INSIGHT 33 : Some community areas have higher arrest counts than others, which suggests that certain neighborhoods may receive more police activity or have higher crime concentrations.<h3>

# %% [markdown]
# <h3>Which community areas show the widest variation in the number of crimes reported each year?</h3>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="Community Area", y="Year", data=chicago, inner="quartile", palette="Set2")

plt.title("Crime Distribution Across Community Areas by Year", fontsize=14)
plt.xlabel("Community Area")
plt.ylabel("Year")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h3>INSIGHT 34 : The chart shows that some community areas have very wide spreads of crime across different years, meaning crime rates in those areas change a lot over time. On the other hand, some community areas have narrower spreads, which means crime there stays more consistent year after year.<h3>

# %% [markdown]
# <h3>How do the total number of crimes compare across different community areas in Chicago?</h3>

# %%
community_trends = chicago.groupby("Community Area").size().reset_index(name="Total_Crimes")

plt.figure(figsize=(12,6))
plt.plot(community_trends["Community Area"], community_trends["Total_Crimes"], marker='o', linestyle='-', color='blue')

plt.title("Total Crimes Across Community Areas", fontsize=14)
plt.xlabel("Community Area")
plt.ylabel("Number of Crimes")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# <h3>INSIGHT 35 : The chart shows that some community areas experience a much higher number of crimes compared to others. A few areas stand out with peaks, meaning they have consistently more reported crimes, while other areas remain low, showing fewer incidents.<h3>
